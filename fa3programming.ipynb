# %% [markdown]
# <a href="https://colab.research.google.com/github/IMKOOLAID4/fa3program/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#fa3prog1
name = input("Name: ")
age = int(input("Age: "))
course = input("Course: ")

# %%
#fa3prog2
grade = int(input ("input your grade:"))

if grade >= 89 and grade <= 100:
    print("grade: passing")
else:
    print("grade: failing")

# %%
#fa3prog3
name = input ("input is your name:")
grade = int(input("input your grade:"))

if grade >= 90 and grade <= 100:
    print("grade: A")
elif grade >= 80 and grade <= 89:
    print("grade: B")
elif grade >= 70 and grade <= 79:
    print("grade: C")
else:
    print("grade: F")
